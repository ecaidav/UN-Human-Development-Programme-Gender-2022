# %% [markdown]
# <a href="https://colab.research.google.com/github/ecaidav/United-Nations-Development-Programme-Gender-2022/blob/main/United-Nations-Development-Programme-Gender-2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import altair as alt
from vega_datasets import data
import numpy as np

pd.set_option('display.max_columns', None)

# %%
inequality_index = pd.read_csv('/content/drive/MyDrive/Columbia University/Spring 2024/Careers/PassBlue/HDR23-24_Statistical_Annex_GII_Table.csv')

# %%
inequality_index['HDI rank'] = pd.to_numeric(inequality_index['HDI rank'], errors='coerce')
inequality_index = inequality_index.dropna(subset=['HDI rank'])
inequality_index['HDI rank'] = inequality_index['HDI rank'].astype(int)

inequality_index['Share of seats in parliament (% held by women)'] = pd.to_numeric(inequality_index['Share of seats in parliament (% held by women)'], errors='coerce')
inequality_index = inequality_index.dropna(subset=['Share of seats in parliament (% held by women)'])
inequality_index['Share of seats in parliament (% held by women)'] = inequality_index['Share of seats in parliament (% held by women)'].astype(int)
# Out:
# <ipython-input-4-574f857304dc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inequality_index['HDI rank'] = inequality_index['HDI rank'].astype(int)
# <ipython-input-4-574f857304dc>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inequality_index['Share of seats in parliament (% held by women)'] = pd.to_numeric(inequality_index['Share of seats in parliament (% held by women)'], errors='coerce')

# %%
inequality_index.head()
# Out:
#       Type Human Development      Country  HDI rank  \
# 0  Country         Very High  Switzerland         1
# 1  Country         Very High       Norway         2
# 2  Country         Very High      Iceland         3
# 4  Country         Very High      Denmark         5
# 5  Country         Very High       Sweden         5
#
#   Gender Inequality Index: Value Gender Inequality Index: Rank  \
# 0                          0.018                             3
# 1                          0.012                             2
# 2                          0.039                             9
# 4                          0.009                             1
# 5                          0.023                             4
#
#   Maternal mortality ratio (deaths per 100,000 live births)  \
# 0                                                  7
# 1                                                  2
# 2                                                  3
# ...

# %%
countries = inequality_index[inequality_index['Type'] == 'Country']

# %%
inequality_index['Gender Inequality Index: Rank'] = pd.to_numeric(inequality_index['Gender Inequality Index: Rank'], errors='coerce')
gender_index = inequality_index[inequality_index['Gender Inequality Index: Rank'].notna()]
gender_index['Gender Inequality Index: Rank'] = gender_index['Gender Inequality Index: Rank'].astype('Int64')
gender_index['HDI_Gender'] = gender_index['HDI rank'] - gender_index['Gender Inequality Index: Rank']
# Out:
# <ipython-input-7-22d9388d0ad3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gender_index['Gender Inequality Index: Rank'] = gender_index['Gender Inequality Index: Rank'].astype('Int64')
# <ipython-input-7-22d9388d0ad3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gender_index['HDI_Gender'] = gender_index['HDI rank'] - gender_index['Gender Inequality Index: Rank']

# %%
gender_index = gender_index.rename(columns={
    'Maternal mortality ratio (deaths per 100,000 live births)': 'Maternal Mortality Ratio',
    'Asolescent birth rate (births per 1,000 women ages 15–19)': 'Adolescent Birth Rate',
    'Share of seats in parliament (% held by women)': 'Parliament Seats Held by Women',
    'Population with at least some secondary education - % Females ages 25 and older': 'Women with Some Secondary Education',
    'Population with at least some secondary education - % Males ages 25 and older': 'Men with Some Secondary Education',
    'Labour force participation rate - % Females ages 15 and older': 'Women in the Labor Force',
    'Labour force participation rate - % Males ages 15 and older': 'Men in the Labor Force',
    'Gender Inequality Index: Value': 'Gender Inequality Index',
    'Gender Inequality Index: Rank': 'GII Rank'
})

# %%
columns_to_percentage = [
    'Parliament Seats Held by Women',
    'Women with Some Secondary Education',
    'Men with Some Secondary Education',
    'Women in the Labor Force',
    'Men in the Labor Force'
]

for column in columns_to_percentage:
    gender_index[column] = pd.to_numeric(gender_index[column], errors='coerce') / 100.0

gender_index[columns_to_percentage] = gender_index[columns_to_percentage].apply(lambda x: x * 100)

for column in columns_to_percentage:
    new_column_name = column + ' %'
    gender_index[new_column_name] = pd.to_numeric(gender_index[column], errors='coerce')

# %%
other_columns_to_format = [
    'Parliament Seats Held by Women %',
    'Women with Some Secondary Education %',
    'Men with Some Secondary Education %',
    'Women in the Labor Force %',
    'Men in the Labor Force %'
]

for column in other_columns_to_format:
    gender_index[column] = pd.to_numeric(gender_index[column.replace(' %', '')], errors='coerce')
    gender_index[column] = gender_index[column].apply(
        lambda x: f"{int(x)}%" if pd.notnull(x) and x.is_integer() else f"{x:.1f}".rstrip('0').rstrip('.') + "%" if pd.notnull(x) else "NaN"
    )

# %%
gender_index.head()
# Out:
#       Type Human Development      Country  HDI rank Gender Inequality Index  \
# 0  Country         Very High  Switzerland         1                   0.018
# 1  Country         Very High       Norway         2                   0.012
# 2  Country         Very High      Iceland         3                   0.039
# 4  Country         Very High      Denmark         5                   0.009
# 5  Country         Very High       Sweden         5                   0.023
#
#    GII Rank Maternal Mortality Ratio  Adolescent Birth Rate  \
# 0         3                        7                    2.2
# 1         2                        2                    2.2
# 2         9                        3                    5.1
# 4         1                        5                    1.8
# 5         4                        5                    3.3
#
#    Parliament Seats Held by Women  Women with Some Secondary Education  \
# 0                            39.0                                 96.9
# ...

# %%
dev = pd.read_csv('/content/drive/MyDrive/Columbia University/Spring 2024/Careers/PassBlue/HDR23-24_Statistical_Annex_GDI_Table_Female.csv')

# %%
dev.head()
# Out:
#                   Country Gender Development Index  \
# 0             Switzerland                    0.971
# 1                  Norway                    0.986
# 2                 Iceland                    0.975
# 3  Hong Kong, China (SAR)                    0.972
# 4                 Denmark                    0.981
#
#   Gender Development Index Group    HDI  Life Expectancy  \
# 0                              2  0.949             85.9
# 1                              1  0.957             85.1
# 2                              1  0.946             84.3
# 3                              2  0.943             86.9
# 4                              1  0.942             83.8
#
#   Expected Years of Schooling Years of Schooling  \
# 0                        16.7               13.5
# 1                        19.5               13.2
# 2                        20.5               13.9
# 3                        17.9               12.0
# 4                        19.4               13.2
#
# ...

# %%
ineq_dev = pd.merge(gender_index, dev, on='Country')

# %%
exact_column_name = 'Gross National Income Per Capita'
ineq_dev[exact_column_name] = ineq_dev[exact_column_name].str.replace(',', '').astype(float)

# %%
new_column_name = '$ Gross National Income Per Capita'
existing_column_name = 'Gross National Income Per Capita'
ineq_dev[new_column_name] = '$' + ineq_dev[existing_column_name].astype(float).map("{:,.0f}".format)

# %%
ineq_dev.head()
# Out:
#       Type Human Development      Country  HDI rank Gender Inequality Index  \
# 0  Country         Very High  Switzerland         1                   0.018
# 1  Country         Very High       Norway         2                   0.012
# 2  Country         Very High      Iceland         3                   0.039
# 3  Country         Very High      Denmark         5                   0.009
# 4  Country         Very High       Sweden         5                   0.023
#
#    GII Rank Maternal Mortality Ratio  Adolescent Birth Rate  \
# 0         3                        7                    2.2
# 1         2                        2                    2.2
# 2         9                        3                    5.1
# 3         1                        5                    1.8
# 4         4                        5                    3.3
#
#    Parliament Seats Held by Women  Women with Some Secondary Education  \
# 0                            39.0                                 96.9
# ...

# %%
chart_1 = alt.Chart(ineq_dev).mark_point(filled=True, clip=False, opacity=0.4).encode(
    x=alt.X('Women with Some Secondary Education:Q',
            title='% Women with Some Secondary Education',
            scale=alt.Scale(domain=[1, 100], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=10, grid=False, labels=True)
           ),
    y=alt.Y('Parliament Seats Held by Women:Q',
            title='% Parliament Seats Held by Women',
            scale=alt.Scale(domain=[1, 60], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=10, grid=False, labels=True)
           ),
    color=alt.Color('Human Development:N',
                    legend=alt.Legend(
                        title="Development Indicator",
                        values=['Very High', 'High', 'Medium', 'Low']
                        )
                   ),
    size=alt.Size('Gender Inequality Index:Q',
                  scale=alt.Scale(domain=[0, 0.82], range=[700, 30]),
                  legend=alt.Legend(
                      title="Gender Inequality Index"
                  )
                 ),
    tooltip=[
        alt.Tooltip('Country:N', title=" "),
        alt.Tooltip('Gender Inequality Index:Q', title='Gender Inequality Index: '),
        alt.Tooltip('Women with Some Secondary Education %:N', title='Secondary Education: '),
        alt.Tooltip('Parliament Seats Held by Women %:N', title='Parliament Seats: ')
    ]
).properties(
    title='Secondary Education x Parliament Seats',
    height=300,
    width=300
)

# %%
chart_2 = alt.Chart(ineq_dev).mark_point(filled=True, clip=False, opacity=0.4).encode(
    x=alt.X('Women with Some Secondary Education:Q',
            title='% Women with Some Secondary Education',
            scale=alt.Scale(domain=[0, 100], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=10, grid=False, labels=True)
           ),
    y=alt.Y('Women in the Labor Force:Q',
            title='% Women in the Labor Force',
            scale=alt.Scale(domain=[5,100], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=10, grid=False, labels=True)
           ),
    color=alt.Color('Human Development:N',
                    legend=alt.Legend(
                        title="Development Indicator",
                        values=['Very High', 'High', 'Medium', 'Low']
                        )
                   ),
    size=alt.Size('Gender Inequality Index:Q',
                  scale=alt.Scale(domain=[0, 0.82], range=[700, 30]),
                  legend=alt.Legend(
                      title="Gender Inequality Index"
                  )
                 ),
    tooltip=[
        alt.Tooltip('Country:N', title=" "),
        alt.Tooltip('Gender Inequality Index:Q', title='Gender Inequality Index: '),
        alt.Tooltip('Women with Some Secondary Education %:N', title='Secondary Education: '),
        alt.Tooltip('Women in the Labor Force %:N', title='Labor Force: ')
    ]
).properties(
    title='Secondary Education x Labor Force',
    height=300,
    width=300
)

# %%
chart_3 = alt.Chart(ineq_dev).mark_point(filled=True, clip=False, opacity=0.4).encode(
    x=alt.X('Life Expectancy:Q',
            title='Life Expectancy',
            scale=alt.Scale(domain=[50,90], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=5, grid=False, labels=True)
           ),
    y=alt.Y('Gross National Income Per Capita:Q',
            title='Average Income (USD)',
            scale=alt.Scale(domain=[1000, 80000], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=10000, grid=False, labels=True)
           ),
    color=alt.Color('Human Development:N',
                    legend=alt.Legend(
                        title="Development Indicator",
                        values=['Very High', 'High', 'Medium', 'Low']
                        )
                   ),
    size=alt.Size('Gender Inequality Index:Q',
                  scale=alt.Scale(domain=[0, 0.8], range=[700, 30]),
                  legend=alt.Legend(
                      title="Gender Inequality Index"
                  )
                 ),
    tooltip=[
        alt.Tooltip('Country:N', title=" "),
        alt.Tooltip('Gender Inequality Index:Q', title='Gender Inequality Index: '),
        alt.Tooltip('Life Expectancy:N', title='Life Expectancy: '),
        alt.Tooltip('$ Gross National Income Per Capita:N', title='Average Income (USD): ')
    ]
).properties(
    title='Life Expectancy x Average Income',
    height=300,
    width=300
)

# %%
chart_4 = alt.Chart(ineq_dev).mark_point(filled=True, clip=False, opacity=0.4).encode(
    x=alt.X('Life Expectancy:Q',
            title='Life Expectancy',
            scale=alt.Scale(domain=[50,90], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=5, grid=False, labels=True)
           ),
    y=alt.Y('Women in the Labor Force:Q',
            title='% Women in the Labor Force',
            scale=alt.Scale(domain=[5,100], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=10, grid=False, labels=True)
           ),
    color=alt.Color('Human Development:N',
                    legend=alt.Legend(
                        title="Development Indicator",
                        values=['Very High', 'High', 'Medium', 'Low']
                        )
                   ),
    size=alt.Size('Gender Inequality Index:Q',
                  scale=alt.Scale(domain=[0, 0.8], range=[700, 30]),
                  legend=alt.Legend(
                      title="Gender Inequality Index"
                  )
                 ),
    tooltip=[
        alt.Tooltip('Country:N', title=" "),
        alt.Tooltip('Gender Inequality Index:Q', title='Gender Inequality Index: '),
        alt.Tooltip('Life Expectancy:N', title='Life Expectancy: '),
        alt.Tooltip('Women in the Labor Force %:N', title='Labor Force: ')
    ]
).properties(
    title='Life Expectancy x Labor Force',
    height=300,
    width=300
)

# %%
chart_5 = alt.Chart(ineq_dev).mark_point(filled=True, clip=False, opacity=0.4).encode(
    x=alt.X('Women in the Labor Force:Q',
            title='% Women in the Labor Force',
            scale=alt.Scale(domain=[1, 100], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=10, grid=False, labels=True)
           ),
    y=alt.Y('Gross National Income Per Capita:Q',
            title='Average Income (USD)',
            scale=alt.Scale(domain=[1000, 80000], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=10000, grid=False, labels=True)
           ),
    color=alt.Color('Human Development:N',
                    legend=alt.Legend(
                        title="Development Indicator",
                        values=['Very High', 'High', 'Medium', 'Low']
                        )
                   ),
    size=alt.Size('Gender Inequality Index:Q',
                  scale=alt.Scale(domain=[0, 0.82], range=[700, 30]),
                  legend=alt.Legend(
                      title="Gender Inequality Index"
                  )
                 ),
    tooltip=[
        alt.Tooltip('Country:N', title=" "),
        alt.Tooltip('Gender Inequality Index:Q', title='Gender Inequality Index: '),
        alt.Tooltip('Women in the Labor Force %:N', title='Labor Force: '),
        alt.Tooltip('$ Gross National Income Per Capita:N', title='Average Income (USD): ')
    ]
).properties(
    title='Labor Force x Average Income',
    height=300,
    width=300
)

# %%
chart_6 = alt.Chart(ineq_dev).mark_point(filled=True, clip=False, opacity=0.4).encode(
    x=alt.X('Maternal Mortality Ratio:Q',
            title='Maternal Mortality Ratio (per 100,000 live births)',
            scale=alt.Scale(domain=[0, 750], nice=False, padding=5),
            axis=alt.Axis(grid=False, labels=True)
           ),
    y=alt.Y('Parliament Seats Held by Women:Q',
            title='% Parliament Seats Held by Women',
            scale=alt.Scale(domain=[1, 60], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=10, grid=False, labels=True)
           ),
    color=alt.Color('Human Development:N',
                    legend=alt.Legend(
                        title="Development Indicator",
                        values=['Very High', 'High', 'Medium', 'Low']
                        )
                   ),
    size=alt.Size('Gender Inequality Index:Q',
                  scale=alt.Scale(domain=[0, 0.82], range=[700, 30]),
                  legend=alt.Legend(
                      title="Gender Inequality Index"
                  )
                 ),
    tooltip=[
        alt.Tooltip('Country:N', title=" "),
        alt.Tooltip('Gender Inequality Index:Q', title='Gender Inequality Index: '),
        alt.Tooltip('Maternal Mortality Ratio:N', title='Maternal Mortality Ratio: '),
        alt.Tooltip('Parliament Seats Held by Women %:N', title='Parliament Seats: ')
    ]
).properties(
    title='Maternal Mortality Rate x Parliament Seats',
    height=300,
    width=300
)

# %%
chart_7 = alt.Chart(ineq_dev).mark_point(filled=True, clip=False, opacity=0.4).encode(
    x=alt.X('Maternal Mortality Ratio:Q',
            title='Maternal Mortality Ratio (per 100,000 live births)',
            scale=alt.Scale(domain=[0, 750], nice=False, padding=5),
            axis=alt.Axis(grid=False, labels=True)
           ),
    y=alt.Y('Women in the Labor Force:Q',
            title='% Women in the Labor Force',
            scale=alt.Scale(domain=[5,100], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=10, grid=False, labels=True)
           ),
    color=alt.Color('Human Development:N',
                    legend=alt.Legend(
                        title="Development Indicator",
                        values=['Very High', 'High', 'Medium', 'Low']
                        )
                   ),
    size=alt.Size('Gender Inequality Index:Q',
                  scale=alt.Scale(domain=[0, 0.82], range=[700, 30]),
                  legend=alt.Legend(
                      title="Gender Inequality Index"
                  )
                 ),
    tooltip=[
        alt.Tooltip('Country:N', title=" "),
        alt.Tooltip('Gender Inequality Index:Q', title='Gender Inequality Index: '),
        alt.Tooltip('Maternal Mortality Ratio:N', title='Maternal Mortality Ratio: '),
        alt.Tooltip('Women in the Labor Force %:N', title='Labor Force: ')
    ]
).properties(
    title='Maternal Mortality Rate x Labor Force',
    height=300,
    width=300
)

# %%
chart_8 = alt.Chart(ineq_dev).mark_point(filled=True, clip=False, opacity=0.4).encode(
    x=alt.X('Women in the Labor Force:Q',
            title='% Women in the Labor Force',
            scale=alt.Scale(domain=[1, 100], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=10, grid=False, labels=True)
           ),
    y=alt.Y('Adolescent Birth Rate:Q',
            title='Adolescent Birth Rate (per 1,000 women, ages 15-19)',
            scale=alt.Scale(domain=[5, 170], nice=False, padding=5),
            axis=alt.Axis(grid=False, labels=True)
           ),
    color=alt.Color('Human Development:N',
                    legend=alt.Legend(
                        title="Development Indicator",
                        values=['Very High', 'High', 'Medium', 'Low']
                        )
                   ),
    size=alt.Size('Gender Inequality Index:Q',
                  scale=alt.Scale(domain=[0, 0.82], range=[700, 30]),
                  legend=alt.Legend(
                      title="Gender Inequality Index"
                  )
                 ),
    tooltip=[
        alt.Tooltip('Country:N', title=" "),
        alt.Tooltip('Gender Inequality Index:Q', title='Gender Inequality Index: '),
        alt.Tooltip('Women in the Labor Force %:N', title='Labor Force: '),
        alt.Tooltip('Adolescent Birth Rate:N', title='Adolescent Birth Rate: ')
    ]
).properties(
    title='Labor Force x Adolescent Birth Rate',
    height=300,
    width=300
)

# %%
chart_9 = alt.Chart(ineq_dev).mark_point(filled=True, clip=False, opacity=0.4).encode(
    x=alt.X('Women with Some Secondary Education:Q',
            title='% Women with Some Secondary Education',
            scale=alt.Scale(domain=[0, 100], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=10, grid=False, labels=True)
           ),
    y=alt.Y('Adolescent Birth Rate:Q',
            title='Adolescent Birth Rate (per 1,000 women, ages 15-19)',
            scale=alt.Scale(domain=[5, 170], nice=False, padding=5),
            axis=alt.Axis(grid=False, labels=True)
           ),
    color=alt.Color('Human Development:N',
                    legend=alt.Legend(
                        title="Development Indicator",
                        values=['Very High', 'High', 'Medium', 'Low']
                        )
                   ),
    size=alt.Size('Gender Inequality Index:Q',
                  scale=alt.Scale(domain=[0, 0.82], range=[700, 30]),
                  legend=alt.Legend(
                      title="Gender Inequality Index"
                  )
                 ),
    tooltip=[
        alt.Tooltip('Country:N', title=" "),
        alt.Tooltip('Gender Inequality Index:Q', title='Gender Inequality Index: '),
        alt.Tooltip('Women with Some Secondary Education %:N', title='Secondary Education: '),
        alt.Tooltip('Adolescent Birth Rate:N', title='Adolescent Birth Rate: ')
    ]
).properties(
    title='Secondary Education x Adolescent Birth Rate',
    height=300,
    width=300
)

# %%
chart_10 = alt.Chart(ineq_dev).mark_point(filled=True, clip=False, opacity=0.4).encode(
    x=alt.X('Maternal Mortality Ratio:Q',
            title='Maternal Mortality Ratio (per 100,000 live births)',
            scale=alt.Scale(domain=[0, 750], nice=False, padding=5),
            axis=alt.Axis(grid=False, labels=True)
           ),
    y=alt.Y('Gross National Income Per Capita:Q',
            title='Average Income (USD)',
            scale=alt.Scale(domain=[1000, 80000], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=10000, grid=False, labels=True)
           ),
    color=alt.Color('Human Development:N',
                    legend=alt.Legend(
                        title="Development Indicator",
                        values=['Very High', 'High', 'Medium', 'Low']
                        )
                   ),
    size=alt.Size('Gender Inequality Index:Q',
                  scale=alt.Scale(domain=[0, 0.82], range=[700, 30]),
                  legend=alt.Legend(
                      title="Gender Inequality Index"
                  )
                 ),
    tooltip=[
        alt.Tooltip('Country:N', title=" "),
        alt.Tooltip('Gender Inequality Index:Q', title='Gender Inequality Index: '),
        alt.Tooltip('Maternal Mortality Ratio:N', title='Maternal Mortality Ratio: '),
        alt.Tooltip('$ Gross National Income Per Capita:N', title='Average Income (USD): ')
    ]
).properties(
    title='Maternal Mortality Rate x Average Income',
    height=300,
    width=300
)

# %%
chart_11 = alt.Chart(ineq_dev).mark_point(filled=True, clip=False, opacity=0.4).encode(
    x=alt.X('Women with Some Secondary Education:Q',
            title='% Women with Some Secondary Education',
            scale=alt.Scale(domain=[0, 100], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=10, grid=False, labels=True)
           ),
    y=alt.Y('Gross National Income Per Capita:Q',
            title='Average Income (USD)',
            scale=alt.Scale(domain=[1000, 80000], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=10000, grid=False, labels=True)
           ),
    color=alt.Color('Human Development:N',
                    legend=alt.Legend(
                        title="Development Indicator",
                        values=['Very High', 'High', 'Medium', 'Low']
                        )
                   ),
    size=alt.Size('Gender Inequality Index:Q',
                  scale=alt.Scale(domain=[0, 0.82], range=[700, 30]),
                  legend=alt.Legend(
                      title="Gender Inequality Index"
                  )
                 ),
    tooltip=[
        alt.Tooltip('Country:N', title=" "),
        alt.Tooltip('Country:N', title=" "),
        alt.Tooltip('Gender Inequality Index:Q', title='Gender Inequality Index: '),
        alt.Tooltip('Women with Some Secondary Education %:N', title='Secondary Education: '),
        alt.Tooltip('$ Gross National Income Per Capita:N', title='Average Income (USD): ')
    ]
).properties(
    title='Secondary Education x Average Income',
    height=300,
    width=300
)

# %%
chart_12 = alt.Chart(ineq_dev).mark_point(filled=True, clip=False, opacity=0.4).encode(
    x=alt.X('Maternal Mortality Ratio:Q',
            title='Maternal Mortality Ratio (per 100,000 live births)',
            scale=alt.Scale(domain=[0, 750], nice=False, padding=5),
            axis=alt.Axis(grid=False, labels=True)
           ),
    y=alt.Y('Adolescent Birth Rate:Q',
            title='Adolescent Birth Rate (per 1,000 women, ages 15-19)',
            scale=alt.Scale(domain=[5, 170], nice=False, padding=5),
            axis=alt.Axis(grid=False, labels=True)
           ),
    color=alt.Color('Human Development:N',
                    legend=alt.Legend(
                        title="Development Indicator",
                        values=['Very High', 'High', 'Medium', 'Low']
                        )
                   ),
    size=alt.Size('Gender Inequality Index:Q',
                  scale=alt.Scale(domain=[0, 0.82], range=[700, 30]),
                  legend=alt.Legend(
                      title="Gender Inequality Index"
                  )
                 ),
    tooltip=[
        alt.Tooltip('Country:N', title=" "),
        alt.Tooltip('Country:N', title=" "),
        alt.Tooltip('Gender Inequality Index:Q', title='Gender Inequality Index: '),
        alt.Tooltip('Maternal Mortality Ratio:N', title='Maternal Mortality Ratio: '),
        alt.Tooltip('Adolescent Birth Rate:N', title='Adolescent Birth Rate: ')
    ]
).properties(
    title='Maternal Mortality Rate x Adolescent Birth Rate',
    height=300,
    width=300
)

# %%
chart_13 = alt.Chart(ineq_dev).mark_point(filled=True, clip=False, opacity=0.4).encode(
    x=alt.X('Life Expectancy:Q',
            title='Life Expectancy',
            scale=alt.Scale(domain=[50,90], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=5, grid=False, labels=True)
           ),
    y=alt.Y('Adolescent Birth Rate:Q',
            title='Adolescent Birth Rate (per 1,000 women, ages 15-19)',
            scale=alt.Scale(domain=[5, 170], nice=False, padding=5),
            axis=alt.Axis(grid=False, labels=True)
           ),
    color=alt.Color('Human Development:N',
                    legend=alt.Legend(
                        title="Development Indicator",
                        values=['Very High', 'High', 'Medium', 'Low']
                        )
                   ),
    size=alt.Size('Gender Inequality Index:Q',
                  scale=alt.Scale(domain=[0, 0.8], range=[700, 30]),
                  legend=alt.Legend(
                      title="Gender Inequality Index"
                  )
                 ),
    tooltip=[
        alt.Tooltip('Country:N', title=" "),
        alt.Tooltip('Gender Inequality Index:Q', title='Gender Inequality Index: '),
        alt.Tooltip('Life Expectancy:N', title='Life Expectancy: '),
        alt.Tooltip('Adolescent Birth Rate:N', title='Adolescent Birth Rate: ')
        ]
).properties(
    title='Life Expectancy x Adolescent Birth Rate',
    height=300,
    width=300
)

# %%
chart_14 = alt.Chart(ineq_dev).mark_point(filled=True, clip=False, opacity=0.4).encode(
    x=alt.X('Life Expectancy:Q',
            title='Life Expectancy',
            scale=alt.Scale(domain=[50,90], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=5, grid=False, labels=True)
           ),
    y=alt.Y('Parliament Seats Held by Women:Q',
            title='% Parliament Seats Held by Women',
            scale=alt.Scale(domain=[1, 60], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=10, grid=False, labels=True)
           ),
    color=alt.Color('Human Development:N',
                    legend=alt.Legend(
                        title="Development Indicator",
                        values=['Very High', 'High', 'Medium', 'Low']
                        )
                   ),
    size=alt.Size('Gender Inequality Index:Q',
                  scale=alt.Scale(domain=[0, 0.8], range=[700, 30]),
                  legend=alt.Legend(
                      title="Gender Inequality Index"
                  )
                 ),
    tooltip=[
        alt.Tooltip('Country:N', title=" "),
        alt.Tooltip('Gender Inequality Index:Q', title='Gender Inequality Index: '),
        alt.Tooltip('Life Expectancy:N', title='Life Expectancy: '),
        alt.Tooltip('Parliament Seats Held by Women %:N', title='Parliament Seats: ')
    ]
).properties(
    title='Life Expectancy x Years of Schooling',
    height=300,
    width=300
)

# %%
chart_15 = alt.Chart(ineq_dev).mark_point(filled=True, clip=False, opacity=0.4).encode(
    x=alt.X('Women in the Labor Force:Q',
            title='% Women in the Labor Force',
            scale=alt.Scale(domain=[5, 100], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=10, grid=False, labels=True)
           ),
    y=alt.Y('Years of Schooling:Q',
            title='Average Years of Schooling',
            scale=alt.Scale(domain=[0, 16], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=1, grid=False, labels=True)
           ),
    color=alt.Color('Human Development:N',
                    legend=alt.Legend(
                        title="Development Indicator",
                        values=['Very High', 'High', 'Medium', 'Low']
                        )
                   ),
    size=alt.Size('Gender Inequality Index:Q',
                  scale=alt.Scale(domain=[0, 0.82], range=[700, 30]),
                  legend=alt.Legend(
                      title="Gender Inequality Index"
                  )
                 ),
    tooltip=[
        alt.Tooltip('Country:N', title=" "),
        alt.Tooltip('Gender Inequality Index:Q', title='Gender Inequality Index: '),
        alt.Tooltip('Women in the Labor Force %:N', title='Labor Force: '),
        alt.Tooltip('Years of Schooling:N', title='Average Years of Schooling: ')
    ]
).properties(
    title='Labor Force x Years of Schooling',
    height=300,
    width=300
)

# %%
chart_16 = alt.Chart(ineq_dev).mark_point(filled=True, clip=False, opacity=0.4).encode(
    x=alt.X('Women in the Labor Force:Q',
            title='% Women in the Labor Force',
            scale=alt.Scale(domain=[0, 100], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=10, grid=False, labels=True)
           ),
    y=alt.Y('Parliament Seats Held by Women:Q',
            title='% Parliament Seats Held by Women',
            scale=alt.Scale(domain=[1, 60], nice=False, padding=5),
            axis=alt.Axis(tickMinStep=10, grid=False, labels=True)
           ),
    color=alt.Color('Human Development:N',
                    legend=alt.Legend(
                        title="Development Indicator",
                        values=['Very High', 'High', 'Medium', 'Low']
                        )
                   ),
    size=alt.Size('Gender Inequality Index:Q',
                  scale=alt.Scale(domain=[0, 0.82], range=[700, 30]),
                  legend=alt.Legend(
                      title="Gender Inequality Index"
                  )
                 ),
    tooltip=[
        alt.Tooltip('Country:N', title=" "),
        alt.Tooltip('Gender Inequality Index:Q', title='Gender Inequality Index: '),
        alt.Tooltip('Women in the Labor Force %:N', title='Labor Force: '),
        alt.Tooltip('Parliament Seats Held by Women %:N', title='Parliament Seats: ')
    ]
).properties(
    title='Labor Force x Parliament Seats',
    height=300,
    width=300
)

# %%
chart_secondary = chart_1 | chart_2 | chart_9 | chart_11
chart_mat = chart_6 | chart_7 | chart_12 | chart_10
chart_life = chart_14 | chart_4 | chart_13 | chart_3
chart_labor = chart_16 | chart_15 | chart_8 | chart_5

# %%
full_chart = (chart_1  |  chart_9  |  chart_11)   &   (chart_6  |  chart_12  |  chart_10)   &   (chart_14  |  chart_13  |  chart_3)   &   (chart_16  |  chart_8  |  chart_5)

# %%
scatter = full_chart.properties(
    title={
        "text": 'Insights from the 2022 Gender Inequality and Gender Development Indices, According to the United Nations Development Programme',
        "subtitle": ['Charts examine relationships across GII and GDI indicators, including parliament seats held by women, adolescent birth rate (per 1,000 women ages 15-19), average income, percentage ',
                     'of women with some secondary education, maternal mortality ratio (per 100,000 live births), life expectancy and percentage of women in the labor force. Details on how the GII is calculated ',
                     'can be found at https://hdr.undp.org/sites/default/files/2023-24_HDR/hdr2023-24_technical_notes.pdf (see: technical notes 3 and 4).'
        ]
    },
).resolve_scale(
    x='independent',
    y='independent'
).configure_title(
    fontSize=14,
    subtitleFontSize=13,
    align='center',
    anchor='start',
    baseline='top',
    orient='top',
    dx=10,
    dy=-15
).configure_axis(
    ticks=False,
    domain=False,
    grid=False,
    labelPadding=5,
    labelFontSize=10,
    titlePadding=10,
    titleFontSize=10,
    titleColor="darkgray"
).configure_concat(
    spacing=40
).configure_view(
    stroke=None
)

scatter
# Out:
# alt.VConcatChart(...)

# %%
ineq_dev = ineq_dev.sort_values(by='HDI_Gender', ascending=False)

# %%
ineq_dev
# Out:
#         Type Human Development                     Country  HDI rank  \
# 157  Country               Low                  Mozambique       183
# 138  Country               Low                      Rwanda       161
# 161  Country               Low                     Burundi       187
# 110  Country            Medium                  Tajikistan       126
# 115  Country            Medium                  Cabo Verde       131
# ..       ...               ...                         ...       ...
# 18   Country         Very High               United States        20
# 71   Country              High          Dominican Republic        82
# 26   Country         Very High                      Cyprus        29
# 51   Country         Very High                      Panama        57
# 68   Country              High  Iran (Islamic Republic of)        78
#
#     Gender Inequality Index  GII Rank Maternal Mortality Ratio  \
# 157                   0.477       118                      127
# ...

# %%
dev = ineq_dev.sort_values(by='HDI_Gender', ascending=False)

# %%
threshold = 0

bar_click_positive = alt.selection_multi(encodings=["x"])
bar_click_negative = alt.selection_multi(encodings=["x"])

bars = alt.Chart(dev).mark_bar().encode(
    x=alt.X("Country:N", title=None, axis=None, sort=alt.EncodingSortField(field="HDI_Gender", order="descending")),
    y=alt.Y("HDI_Gender:Q", title='Rank Spread'),
    color=alt.condition(bar_click_positive, alt.value("#22a3dd"), alt.value("black"))
)

tooltip_layer_positive = bars.encode(
    tooltip=[
        alt.Tooltip("Country:N", title=" "),
        alt.Tooltip("HDI rank:Q", title="HDI Rank"),
        alt.Tooltip("GII Rank:Q", title="GII Rank")
    ]
).transform_filter(
    bar_click_positive
).add_selection(
    bar_click_positive
)

tooltip_layer_negative = bars.encode(
    tooltip=[
        alt.Tooltip("Country:N", title=" "),
        alt.Tooltip("HDI rank:Q", title="HDI Rank"),
        alt.Tooltip("GII Rank:Q", title="GII Rank")
    ]
).transform_filter(
    bar_click_negative
).add_selection(
    bar_click_negative
)

rule = alt.Chart().mark_rule(color='black').encode(
    y=alt.datum(threshold)
)

label_1 = rule.mark_text(
    x="width",
    dx=25,
    dy=50,
    align="left",
    baseline="middle",
    text='GII < HDI',
    fontSize=10,
    fontWeight='bold'
)

label_2 = rule.mark_text(
    x="width",
    dx=25,
    dy=-50,
    align="left",
    baseline="middle",
    text='GII > HDI',
    fontSize=10,
    fontWeight='bold'
)

bar = (bars + tooltip_layer_positive + tooltip_layer_negative + rule + label_1 + label_2).properties(
    width=1800,
    height=800,
    title={
        "text": 'Comparative Disparity Between 2022 Gender Equity and Human Development Indices, According to the United Nations Development Programme',
        "subtitle": [
            """Values reflect the degree to which a country ranks higher on the Gender Inequality Index than the Human Development Index. The GII is defined as "a composite """,
            """measure reflecting inequality in achievement between women and men in three dimensions: reproductive health, empowerment and the labour market." Details on """,
            """how the GII is calculated can be found at https://hdr.undp.org/sites/default/files/2023-24_HDR/hdr2023-24_technical_notes.pdf (see: figure three)."""
        ]
    }
).configure_title(
    fontSize=14,
    subtitleFontSize=13,
    align='left',
    anchor='start',
    baseline='bottom',
    orient='bottom',
    dx=35,
    dy=15
).configure_axis(
    ticks=False,
    grid=False
).configure_view(
    stroke=None
)

bar
# Out:
# alt.LayerChart(...)
